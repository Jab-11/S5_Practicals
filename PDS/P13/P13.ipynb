# %% [markdown]
# <a href="https://colab.research.google.com/github/Jab-11/S5_Practicals/blob/main/PDS/P13/P13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pract-13: <br>Apply the hashing trick on the attributes of the loan dataset.

# %%
import pandas as pd

# %%
df = pd.read_csv('loan_data_set.csv')

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
def hashing_trick(input_string, vector_size=20):
  if pd.isna(input_string):
    input_string = "Unknown"
  feature_vector = [0] * vector_size
  for word in input_string.split(' '):
    index = abs(hash(word)) % vector_size
    feature_vector[index] = 1
  binary_string = ''.join(map(str, feature_vector))
  return binary_string

# %%
hashed_loan_id_data = []
for index, data in df.iterrows():
  hashed_loan_id_data.append(hashing_trick(data['Loan_ID']))
hashed_loan_id_data[0]
# Out:
# '00000000000000010000'

# %%
hashed_loan_id_df = pd.DataFrame(hashed_loan_id_data, columns=['Hashed_Loan_ID'])
hashed_loan_id_df = pd.concat([df['Loan_ID'],hashed_loan_id_df],axis=1)
hashed_loan_id_df.head()
# Out:
#     Loan_ID        Hashed_Loan_ID
# 0  LP001002  00000000000000010000
# 1  LP001003  00000000001000000000
# 2  LP001005  00000000000000000100
# 3  LP001006  10000000000000000000
# 4  LP001008  00000000000000000100

# %%
hashed_income_data = []
for index, data in df.iterrows():
    hashed_income_data.append(hashing_trick(str(data['ApplicantIncome'])))
hashed_income_data[0]
# Out:
# '00001000000000000000'

# %%
hashed_income_df = pd.DataFrame(hashed_income_data, columns=['Hashed_Income'])
hashed_income_df = pd.concat([df['ApplicantIncome'],hashed_income_df],axis=1)
hashed_income_df.head()
# Out:
#    ApplicantIncome         Hashed_Income
# 0             5849  00001000000000000000
# 1             4583  00000000000000000100
# 2             3000  00000000000100000000
# 3             2583  00000000000010000000
# 4             6000  00001000000000000000
